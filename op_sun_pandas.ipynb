# %%
import pandas as pd

# %%
print(pd.__version__)
# Out:
# 2.3.3

# %%
data={
"Name":["Ali","Sara","Jhon"],
"Age":[22,25,21],
"Salary":[30000,45000,50000]
}
df=pd.DataFrame(data)
df
# Out:
#    Name  Age  Salary
# 0   Ali   22   30000
# 1  Sara   25   45000
# 2  Jhon   21   50000

# %%
data={
"Name":["Siya","Nina","ken"],
"Marks":[70,80,90],
"city":["jsr","pune","bokaro"]
}
df=pd.DataFrame(data)
df
# Out:
#    Name  Marks    city
# 0  Siya     70     jsr
# 1  Nina     80    pune
# 2   ken     90  bokaro

# %%
import pandas as pd 
df = pd.read_csv(r"C:\Users\ASUS 1\Downloads\archive\Amazon Sale Report.csv")
df
# Out:
# C:\Users\ASUS 1\AppData\Local\Temp\ipykernel_16728\3005046150.py:2: DtypeWarning: Columns (23) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(r"C:\Users\ASUS 1\Downloads\archive\Amazon Sale Report.csv")
#          index             Order ID      Date                        Status  \
# 0            0  405-8078784-5731545  04-30-22                     Cancelled
# 1            1  171-9198151-1101146  04-30-22  Shipped - Delivered to Buyer
# 2            2  404-0687676-7273146  04-30-22                       Shipped
# 3            3  403-9615377-8133951  04-30-22                     Cancelled
# 4            4  407-1069790-7240320  04-30-22                       Shipped
# ...        ...                  ...       ...                           ...
# 128970  128970  406-6001380-7673107  05-31-22                       Shipped
# 128971  128971  402-9551604-7544318  05-31-22                       Shipped
# ...

# %%
df.head()
# Out:
#    index             Order ID      Date                        Status  \
# 0      0  405-8078784-5731545  04-30-22                     Cancelled
# 1      1  171-9198151-1101146  04-30-22  Shipped - Delivered to Buyer
# 2      2  404-0687676-7273146  04-30-22                       Shipped
# 3      3  403-9615377-8133951  04-30-22                     Cancelled
# 4      4  407-1069790-7240320  04-30-22                       Shipped
#
#   Fulfilment Sales Channel  ship-service-level    Style              SKU  \
# 0   Merchant      Amazon.in           Standard   SET389   SET389-KR-NP-S
# 1   Merchant      Amazon.in           Standard  JNE3781  JNE3781-KR-XXXL
# 2     Amazon      Amazon.in          Expedited  JNE3371    JNE3371-KR-XL
# 3   Merchant      Amazon.in           Standard    J0341       J0341-DR-L
# 4     Amazon      Amazon.in          Expedited  JNE3671  JNE3671-TU-XXXL
#
#         Category  ... currency  Amount    ship-city   ship-state  \
# ...

# %%
df.tail()
# Out:
#          index             Order ID      Date   Status Fulfilment  \
# 128970  128970  406-6001380-7673107  05-31-22  Shipped     Amazon
# 128971  128971  402-9551604-7544318  05-31-22  Shipped     Amazon
# 128972  128972  407-9547469-3152358  05-31-22  Shipped     Amazon
# 128973  128973  402-6184140-0545956  05-31-22  Shipped     Amazon
# 128974  128974  408-7436540-8728312  05-31-22  Shipped     Amazon
#
#        Sales Channel  ship-service-level    Style             SKU  \
# 128970      Amazon.in          Expedited  JNE3697   JNE3697-KR-XL
# 128971      Amazon.in          Expedited   SET401  SET401-KR-NP-M
# 128972      Amazon.in          Expedited    J0157    J0157-DR-XXL
# 128973      Amazon.in          Expedited    J0012    J0012-SKD-XS
# 128974      Amazon.in          Expedited    J0003     J0003-SET-S
#
#              Category  ... currency  Amount  ship-city    ship-state  \
# 128970          kurta  ...      INR   517.0  HYDERABAD     TELANGANA
# ...

# %%
df.columns
# Out:
# Index(['index', 'Order ID', 'Date', 'Status', 'Fulfilment', 'Sales Channel ',
#        'ship-service-level', 'Style', 'SKU', 'Category', 'Size', 'ASIN',
#        'Courier Status', 'Qty', 'currency', 'Amount', 'ship-city',
#        'ship-state', 'ship-postal-code', 'ship-country', 'promotion-ids',
#        'B2B', 'fulfilled-by', 'Unnamed: 22'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 128975 entries, 0 to 128974
# Data columns (total 24 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   index               128975 non-null  int64
#  1   Order ID            128975 non-null  object
#  2   Date                128975 non-null  object
#  3   Status              128975 non-null  object
#  4   Fulfilment          128975 non-null  object
#  5   Sales Channel       128975 non-null  object
#  6   ship-service-level  128975 non-null  object
#  7   Style               128975 non-null  object
#  8   SKU                 128975 non-null  object
#  9   Category            128975 non-null  object
#  10  Size                128975 non-null  object
#  11  ASIN                128975 non-null  object
#  12  Courier Status      122103 non-null  object
#  13  Qty                 128975 non-null  int64
#  14  currency            121180 non-null  object
# ...

# %%
df.shape
# Out:
# (128975, 24)

# %%
df.describe()
# Out:
#                index            Qty         Amount  ship-postal-code
# count  128975.000000  128975.000000  121180.000000     128942.000000
# mean    64487.000000       0.904431     648.561465     463966.236509
# std     37232.019822       0.313354     281.211687     191476.764941
# min         0.000000       0.000000       0.000000     110001.000000
# 25%     32243.500000       1.000000     449.000000     382421.000000
# 50%     64487.000000       1.000000     605.000000     500033.000000
# 75%     96730.500000       1.000000     788.000000     600024.000000
# max    128974.000000      15.000000    5584.000000     989898.000000

# %%
len(df)
# Out:
# 128975

# %%
df["ship-state"].unique()
# Out:
# array(['MAHARASHTRA', 'KARNATAKA', 'PUDUCHERRY', 'TAMIL NADU',
#        'UTTAR PRADESH', 'CHANDIGARH', 'TELANGANA', 'ANDHRA PRADESH',
#        'RAJASTHAN', 'DELHI', 'HARYANA', 'ASSAM', 'JHARKHAND',
#        'CHHATTISGARH', 'ODISHA', 'KERALA', 'MADHYA PRADESH',
#        'WEST BENGAL', 'NAGALAND', 'Gujarat', 'UTTARAKHAND', 'BIHAR',
#        'JAMMU & KASHMIR', 'PUNJAB', 'HIMACHAL PRADESH',
#        'ARUNACHAL PRADESH', 'MANIPUR', 'Goa', 'MEGHALAYA', 'GOA',
#        'TRIPURA', 'LADAKH', 'DADRA AND NAGAR', 'SIKKIM', 'Delhi', nan,
#        'ANDAMAN & NICOBAR ', 'Punjab', 'Rajshthan', 'Manipur',
#        'rajasthan', 'Odisha', 'NL', 'Bihar', 'MIZORAM', 'punjab',
#        'New Delhi', 'Rajasthan', 'Punjab/Mohali/Zirakpur', 'Puducherry',
#        'delhi', 'RJ', 'Chandigarh', 'orissa', 'LAKSHADWEEP', 'goa', 'PB',
#        'APO', 'Arunachal Pradesh', 'AR', 'Pondicherry', 'Sikkim',
#        'Arunachal pradesh', 'Nagaland', 'bihar', 'Mizoram', 'rajsthan',
# ...

# %%
df["ship-state"].nunique()
# Out:
# 69

# %%
df["Status"].value_counts()
# Out:
# Status
# Shipped                          77804
# Shipped - Delivered to Buyer     28769
# Cancelled                        18332
# Shipped - Returned to Seller      1953
# Shipped - Picked Up                973
# Pending                            658
# Pending - Waiting for Pick Up      281
# Shipped - Returning to Seller      145
# Shipped - Out for Delivery          35
# Shipped - Rejected by Buyer         11
# Shipping                             8
# Shipped - Lost in Transit            5
# Shipped - Damaged                    1
# Name: count, dtype: int64

# %%
df["Status"]
# Out:
# 0                            Cancelled
# 1         Shipped - Delivered to Buyer
# 2                              Shipped
# 3                            Cancelled
# 4                              Shipped
#                       ...
# 128970                         Shipped
# 128971                         Shipped
# 128972                         Shipped
# 128973                         Shipped
# 128974                         Shipped
# Name: Status, Length: 128975, dtype: object

# %%
df[["Status","ship-state","Amount"]]
# Out:
#                               Status    ship-state   Amount
# 0                          Cancelled   MAHARASHTRA   647.62
# 1       Shipped - Delivered to Buyer     KARNATAKA   406.00
# 2                            Shipped   MAHARASHTRA   329.00
# 3                          Cancelled    PUDUCHERRY   753.33
# 4                            Shipped    TAMIL NADU   574.00
# ...                              ...           ...      ...
# 128970                       Shipped     TELANGANA   517.00
# 128971                       Shipped       HARYANA   999.00
# 128972                       Shipped     TELANGANA   690.00
# 128973                       Shipped       Gujarat  1199.00
# 128974                       Shipped  CHHATTISGARH   696.00
#
# [128975 rows x 3 columns]

# %%
df[["Status","ship-state","Amount"]].head()
# Out:
#                          Status   ship-state  Amount
# 0                     Cancelled  MAHARASHTRA  647.62
# 1  Shipped - Delivered to Buyer    KARNATAKA  406.00
# 2                       Shipped  MAHARASHTRA  329.00
# 3                     Cancelled   PUDUCHERRY  753.33
# 4                       Shipped   TAMIL NADU  574.00

# %%
df[["Category","Amount"]]
# Out:
#              Category   Amount
# 0                 Set   647.62
# 1               kurta   406.00
# 2               kurta   329.00
# 3       Western Dress   753.33
# 4                 Top   574.00
# ...               ...      ...
# 128970          kurta   517.00
# 128971            Set   999.00
# 128972  Western Dress   690.00
# 128973            Set  1199.00
# 128974            Set   696.00
#
# [128975 rows x 2 columns]

# %%
df.head()
# Out:
#    index             Order ID      Date                        Status  \
# 0      0  405-8078784-5731545  04-30-22                     Cancelled
# 1      1  171-9198151-1101146  04-30-22  Shipped - Delivered to Buyer
# 2      2  404-0687676-7273146  04-30-22                       Shipped
# 3      3  403-9615377-8133951  04-30-22                     Cancelled
# 4      4  407-1069790-7240320  04-30-22                       Shipped
#
#   Fulfilment Sales Channel  ship-service-level    Style              SKU  \
# 0   Merchant      Amazon.in           Standard   SET389   SET389-KR-NP-S
# 1   Merchant      Amazon.in           Standard  JNE3781  JNE3781-KR-XXXL
# 2     Amazon      Amazon.in          Expedited  JNE3371    JNE3371-KR-XL
# 3   Merchant      Amazon.in           Standard    J0341       J0341-DR-L
# 4     Amazon      Amazon.in          Expedited  JNE3671  JNE3671-TU-XXXL
#
#         Category  ... currency  Amount    ship-city   ship-state  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 128975 entries, 0 to 128974
# Data columns (total 24 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   index               128975 non-null  int64
#  1   Order ID            128975 non-null  object
#  2   Date                128975 non-null  object
#  3   Status              128975 non-null  object
#  4   Fulfilment          128975 non-null  object
#  5   Sales Channel       128975 non-null  object
#  6   ship-service-level  128975 non-null  object
#  7   Style               128975 non-null  object
#  8   SKU                 128975 non-null  object
#  9   Category            128975 non-null  object
#  10  Size                128975 non-null  object
#  11  ASIN                128975 non-null  object
#  12  Courier Status      122103 non-null  object
#  13  Qty                 128975 non-null  int64
#  14  currency            121180 non-null  object
# ...

# %%
df.describe()
# Out:
#                index            Qty         Amount  ship-postal-code
# count  128975.000000  128975.000000  121180.000000     128942.000000
# mean    64487.000000       0.904431     648.561465     463966.236509
# std     37232.019822       0.313354     281.211687     191476.764941
# min         0.000000       0.000000       0.000000     110001.000000
# 25%     32243.500000       1.000000     449.000000     382421.000000
# 50%     64487.000000       1.000000     605.000000     500033.000000
# 75%     96730.500000       1.000000     788.000000     600024.000000
# max    128974.000000      15.000000    5584.000000     989898.000000

# %%
df["Category"].value_counts()
# Out:
# Category
# Set              50284
# kurta            49877
# Western Dress    15500
# Top              10622
# Ethnic Dress      1159
# Blouse             926
# Bottom             440
# Saree              164
# Dupatta              3
# Name: count, dtype: int64

# %%
df["Amount"].mean()
# Out:
# np.float64(648.5614647631622)

# %%
df.isnull().sum()
# Out:
# index                     0
# Order ID                  0
# Date                      0
# Status                    0
# Fulfilment                0
# Sales Channel             0
# ship-service-level        0
# Style                     0
# SKU                       0
# Category                  0
# Size                      0
# ASIN                      0
# Courier Status         6872
# Qty                       0
# currency               7795
# Amount                 7795
# ship-city                33
# ship-state               33
# ship-postal-code         33
# ship-country             33
# promotion-ids         49153
# B2B                       0
# fulfilled-by          89698
# Unnamed: 22           49050
# dtype: int64

# %%
df.dtypes
# Out:
# index                   int64
# Order ID               object
# Date                   object
# Status                 object
# Fulfilment             object
# Sales Channel          object
# ship-service-level     object
# Style                  object
# SKU                    object
# Category               object
# Size                   object
# ASIN                   object
# Courier Status         object
# Qty                     int64
# currency               object
# Amount                float64
# ship-city              object
# ship-state             object
# ship-postal-code      float64
# ship-country           object
# promotion-ids          object
# B2B                      bool
# fulfilled-by           object
# Unnamed: 22            object
# dtype: object

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.groupby("Category")["Amount"].mean().sort_values(ascending=False).head(10)
# Out:
# Category
# Set              833.385571
# Saree            799.572645
# Western Dress    762.790580
# Ethnic Dress     723.895389
# Top              526.098603
# Blouse           520.327106
# kurta            455.927108
# Bottom           358.733286
# Dupatta          305.000000
# Name: Amount, dtype: float64

# %%
df.groupby("Category")["Amount"].sum().sort_values(ascending=False)
# Out:
# Category
# Set              39204124.03
# kurta            21299546.70
# Western Dress    11216072.69
# Top               5347792.30
# Ethnic Dress       791217.66
# Blouse             458408.18
# Bottom             150667.98
# Saree              123933.76
# Dupatta               915.00
# Name: Amount, dtype: float64

# %%
df.isnull().sum().sort_values(ascending=False)
# Out:
# fulfilled-by          89698
# promotion-ids         49153
# Unnamed: 22           49050
# currency               7795
# Amount                 7795
# Courier Status         6872
# ship-country             33
# ship-postal-code         33
# ship-state               33
# ship-city                33
# ship-service-level        0
# Style                     0
# Date                      0
# B2B                       0
# Status                    0
# Fulfilment                0
# Sales Channel             0
# Qty                       0
# Order ID                  0
# ASIN                      0
# Size                      0
# Category                  0
# SKU                       0
# index                     0
# dtype: int64

# %%
df["Unnamed: 22"].head(200000)
# Out:
# 0           NaN
# 1           NaN
# 2           NaN
# 3           NaN
# 4           NaN
#           ...
# 128970    False
# 128971    False
# 128972    False
# 128973    False
# 128974    False
# Name: Unnamed: 22, Length: 128975, dtype: object

# %%
df["Unnamed: 22"].value_counts(dropna=False)
# Out:
# Unnamed: 22
# False    79925
# NaN      49050
# Name: count, dtype: int64

# %%
df["fulfilled-by"].value_counts(dropna=False)
# Out:
# fulfilled-by
# NaN          89698
# Easy Ship    39277
# Name: count, dtype: int64

# %%
df[df["Amount"].isnull()].head(10)
# Out:
#      index             Order ID      Date     Status Fulfilment  \
# 8        8  407-5443024-5233168  04-30-22  Cancelled     Amazon
# 29      29  404-5933402-8801952  04-30-22  Cancelled   Merchant
# 65      65  171-4137548-0481151  04-30-22  Cancelled     Amazon
# 84      84  403-9950518-0349133  04-30-22  Cancelled     Amazon
# 95      95  405-9112089-3379536  04-30-22  Cancelled     Amazon
# 101    101  402-7841951-1872363  04-30-22  Cancelled     Amazon
# 132    132  171-0293372-4913973  04-30-22  Cancelled     Amazon
# 139    139  403-6442534-2769112  04-30-22  Cancelled     Amazon
# 155    155  402-8078642-8565124  04-30-22  Cancelled     Amazon
# 165    165  406-0218328-1773963  04-30-22  Cancelled     Amazon
#
#     Sales Channel  ship-service-level     Style                  SKU Category  \
# 8        Amazon.in          Expedited    SET200  SET200-KR-NP-A-XXXL      Set
# 29       Amazon.in           Standard   JNE2132  JNE2132-KR-398-XXXL    kurta
# ...

# %%
df["currency"].value_counts(dropna=False)
# Out:
# currency
# INR    121180
# NaN      7795
# Name: count, dtype: int64

# %%
df[df["currency"].isnull()].head(10)
# Out:
#      index             Order ID       Date     Status Fulfilment  \
# 8        8  407-5443024-5233168 2022-04-30  Cancelled     Amazon
# 29      29  404-5933402-8801952 2022-04-30  Cancelled   Merchant
# 65      65  171-4137548-0481151 2022-04-30  Cancelled     Amazon
# 84      84  403-9950518-0349133 2022-04-30  Cancelled     Amazon
# 95      95  405-9112089-3379536 2022-04-30  Cancelled     Amazon
# 101    101  402-7841951-1872363 2022-04-30  Cancelled     Amazon
# 132    132  171-0293372-4913973 2022-04-30  Cancelled     Amazon
# 139    139  403-6442534-2769112 2022-04-30  Cancelled     Amazon
# 155    155  402-8078642-8565124 2022-04-30  Cancelled     Amazon
# 165    165  406-0218328-1773963 2022-04-30  Cancelled     Amazon
#
#     Sales Channel  ship-service-level     Style                  SKU Category  \
# 8        Amazon.in          Expedited    SET200  SET200-KR-NP-A-XXXL      Set
# 29       Amazon.in           Standard   JNE2132  JNE2132-KR-398-XXXL    kurta
# ...

# %%
df["Date"]=pd.to_datetime(df["Date"],dayfirst = True)

# %%
df["Date"].head(10)
# Out:
# 0   2022-04-30
# 1   2022-04-30
# 2   2022-04-30
# 3   2022-04-30
# 4   2022-04-30
# 5   2022-04-30
# 6   2022-04-30
# 7   2022-04-30
# 8   2022-04-30
# 9   2022-04-30
# Name: Date, dtype: datetime64[ns]

# %%
df["Date"] = pd.to_datetime(df["Date"], format="%m-%d-%Y")

# %%
df["Amount"].dtype
# Out:
# dtype('float64')

# %%
df["Category"] = df["Category"].str.strip()

# %%
df["Status"] = df["Status"].str.strip()

# %%
df["Category"].value_counts()
# Out:
# Category
# Set              50284
# kurta            49877
# Western Dress    15500
# Top              10622
# Ethnic Dress      1159
# Blouse             926
# Bottom             440
# Saree              164
# Dupatta              3
# Name: count, dtype: int64

# %%
df["Status"].value_counts()
# Out:
# Status
# Shipped                          77804
# Shipped - Delivered to Buyer     28769
# Cancelled                        18332
# Shipped - Returned to Seller      1953
# Shipped - Picked Up                973
# Pending                            658
# Pending - Waiting for Pick Up      281
# Shipped - Returning to Seller      145
# Shipped - Out for Delivery          35
# Shipped - Rejected by Buyer         11
# Shipping                             8
# Shipped - Lost in Transit            5
# Shipped - Damaged                    1
# Name: count, dtype: int64

# %%
df["ship-city"].value_counts().head(50)
# Out:
# ship-city
# BENGALURU             11900
# HYDERABAD              9128
# MUMBAI                 7124
# NEW DELHI              6340
# CHENNAI                6288
# PUNE                   4618
# KOLKATA                2844
# GURUGRAM               1956
# THANE                  1877
# LUCKNOW                1627
# NOIDA                  1627
# GHAZIABAD              1485
# AHMEDABAD              1445
# NAVI MUMBAI            1403
# BANGALORE              1362
# JAIPUR                 1062
# COIMBATORE              891
# VISAKHAPATNAM           858
# FARIDABAD               820
# PATNA                   816
# BHUBANESWAR             780
# PIMPRI CHINCHWAD        754
# GUWAHATI                740
# NAGPUR                  733
# VADODARA                710
# THIRUVANANTHAPURAM      679
# DEHRADUN                633
# SECUNDERABAD            623
# GREATER NOIDA           564
# SURAT                   564
# INDORE                  557
# KALYAN                  547
# ...

# %%
df["ship-city"]=df["ship-city"].str.upper()

# %%
df["ship-city"]=df["ship-city"].str.strip().str.replace(".","",regex=False)

# %%
df["ship-city"].unique()
# Out:
# array(['MUMBAI', 'BENGALURU', 'NAVI MUMBAI', ..., 'CHERUKUNNU (PO)',
#        'GULABPURA, DISTT BHILWARA', 'PRAYAGRAJ (ALLAHABAD)'],
#       shape=(7273,), dtype=object)

# %%
df["ship-city"].head(20)
# Out:
# 0          MUMBAI
# 1       BENGALURU
# 2     NAVI MUMBAI
# 3      PUDUCHERRY
# 4         CHENNAI
# 5       GHAZIABAD
# 6      CHANDIGARH
# 7       HYDERABAD
# 8       HYDERABAD
# 9         CHENNAI
# 10        CHENNAI
# 11          NOIDA
# 12       AMRAVATI
# 13         MUMBAI
# 14         MUMBAI
# 15       GUNTAKAL
# 16         JAIPUR
# 17      NEW DELHI
# 18        GURGAON
# 19      BENGALURU
# Name: ship-city, dtype: object

# %%
df["Amount"].describe()
# Out:
# count    121180.000000
# mean        648.561465
# std         281.211687
# min           0.000000
# 25%         449.000000
# 50%         605.000000
# 75%         788.000000
# max        5584.000000
# Name: Amount, dtype: float64

# %%
df[df["Amount"] == 0][["Status","Amount"]].value_counts()
# Out:
# Status                         Amount
# Shipped                        0.0       1518
# Shipped - Delivered to Buyer   0.0        716
# Shipped - Returned to Seller   0.0         51
# Shipped - Picked Up            0.0         28
# Pending                        0.0         17
# Pending - Waiting for Pick Up  0.0          9
# Shipped - Lost in Transit      0.0          2
# Shipped - Returning to Seller  0.0          2
# Name: count, dtype: int64

# %%
df[df["Amount"]==0].head(10)
# Out:
#      index             Order ID       Date                        Status  \
# 212    212  408-4547464-4180323 2022-04-30  Shipped - Delivered to Buyer
# 374    374  408-5020509-5674715 2022-04-30  Shipped - Returned to Seller
# 385    385  408-3137526-3167563 2022-04-30                       Shipped
# 388    388  408-7971979-8745937 2022-04-30  Shipped - Delivered to Buyer
# 392    392  408-0912805-7526753 2022-04-30                       Shipped
# 436    436  408-6466311-6949931 2022-04-30                       Shipped
# 441    441  408-6732772-4525113 2022-04-30  Shipped - Delivered to Buyer
# 446    446  408-7937211-8974712 2022-04-30                       Shipped
# 449    449  408-6348199-2089932 2022-04-30                       Shipped
# 729    729  408-4193711-8156307 2022-04-30  Shipped - Delivered to Buyer
#
#     Fulfilment Sales Channel  ship-service-level    Style               SKU  \
# 212   Merchant      Amazon.in           Standard  JNE3568    JNE3568-KR-XXL
# ...

# %%
df["Qty"].value_counts().sort_index()
# Out:
# Qty
# 0      12807
# 1     115780
# 2        341
# 3         32
# 4          9
# 5          2
# 8          1
# 9          1
# 13         1
# 15         1
# Name: count, dtype: int64

# %%
df[df["Qty"]==0]["Status"].value_counts()
# Out:
# Status
# Cancelled                       12701
# Shipped                            93
# Shipped - Delivered to Buyer        8
# Shipped - Returned to Seller        3
# Pending                             2
# Name: count, dtype: int64

# %%
df[df["Category"] == "Set"].head()
# Out:
#     index             Order ID       Date     Status Fulfilment  \
# 0       0  405-8078784-5731545 2022-04-30  Cancelled   Merchant
# 5       5  404-1490984-4578765 2022-04-30    Shipped     Amazon
# 6       6  408-5748499-6859555 2022-04-30    Shipped     Amazon
# 8       8  407-5443024-5233168 2022-04-30  Cancelled     Amazon
# 13     13  408-7955685-3083534 2022-04-30    Shipped     Amazon
#
#    Sales Channel  ship-service-level   Style                  SKU Category  \
# 0       Amazon.in           Standard  SET389       SET389-KR-NP-S      Set
# 5       Amazon.in          Expedited  SET264      SET264-KR-NP-XL      Set
# 6       Amazon.in          Expedited   J0095          J0095-SET-L      Set
# 8       Amazon.in          Expedited  SET200  SET200-KR-NP-A-XXXL      Set
# 13      Amazon.in          Expedited  SET182      SET182-KR-DH-XS      Set
#
#     ... currency  Amount   ship-city     ship-state ship-postal-code  \
# ...

# %%
df["Order ID"].duplicated().sum()
# Out:
# np.int64(8597)

# %%
df[df["Order ID"] == df["Order ID"].iloc[0]]
# Out:
#    index             Order ID       Date     Status Fulfilment Sales Channel   \
# 0      0  405-8078784-5731545 2022-04-30  Cancelled   Merchant      Amazon.in
#
#   ship-service-level   Style             SKU Category  ... currency  Amount  \
# 0           Standard  SET389  SET389-KR-NP-S      Set  ...      INR  647.62
#
#   ship-city   ship-state ship-postal-code  ship-country promotion-ids    B2B  \
# 0    MUMBAI  MAHARASHTRA         400081.0            IN           NaN  False
#
#    fulfilled-by Unnamed: 22
# 0     Easy Ship         NaN
#
# [1 rows x 24 columns]

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df[df[["ship-city","ship-state","ship-postal-code","ship-country"]].isnull().any(axis=1)]
# Out:
#          index             Order ID       Date                        Status  \
# 1871      1871  404-0566904-4825137 2022-04-29                       Shipped
# 1872      1872  404-0566904-4825137 2022-04-29                       Shipped
# 8752      8752  406-4003386-8768363 2022-04-25                       Shipped
# 11215    11215  402-0107720-7057168 2022-04-23                       Shipped
# 13252    13252  407-4532637-8415521 2022-04-22                     Cancelled
# 15688    15688  404-9229894-8608305 2022-04-21                       Shipped
# 16787    16787  402-4919636-4333150 2022-04-20  Shipped - Delivered to Buyer
# 18351    18351  405-4927647-8064368 2022-04-19                       Shipped
# 22930    22930  402-8628677-0457954 2022-04-16  Shipped - Returned to Seller
# 24986    24986  406-4079063-8291520 2022-04-15                     Cancelled
# 30379    30379  404-7506843-7913132 2022-12-04  Shipped - Delivered to Buyer
# ...

# %%
df = df.drop(columns="Unnamed: 22")

# %%
df.to_csv("amazon_orders_cleaned.csv",index=False)

# %%
df.groupby("Category")["Amount"].sum().sort_values(ascending=False)
# Out:
# Category
# Set              39204124.03
# kurta            21299546.70
# Western Dress    11216072.69
# Top               5347792.30
# Ethnic Dress       791217.66
# Blouse             458408.18
# Bottom             150667.98
# Saree              123933.76
# Dupatta               915.00
# Name: Amount, dtype: float64

# %%
df.groupby("Category")["Qty"].sum().sort_values(ascending=False)
# Out:
# Category
# Set              45289
# kurta            45045
# Western Dress    13943
# Top               9903
# Ethnic Dress      1053
# Blouse             863
# Bottom             398
# Saree              152
# Dupatta              3
# Name: Qty, dtype: int64

# %%
import os
os.getcwd()
# Out:
# 'C:\\Users\\ASUS 1'

# %%
os.listdir()
# Out:
# ['.anaconda',
#  '.android',
#  '.conda',
#  '.continuum',
#  '.gitconfig',
#  '.ipynb_checkpoints',
#  '.ipython',
#  '.jupyter',
#  '.matplotlib',
#  '.virtual_documents',
#  '.vscode',
#  '.vscode-shared',
#  'amazon_orders_cleaned.csv',
#  'anaconda3',
#  'anaconda_projects',
#  'AppData',
#  'Application Data',
#  'Contacts',
#  'Cookies',
#  'Desktop',
#  'Documents',
#  'Downloads',
#  'Favorites',
#  'Links',
#  'Local Settings',
#  'Microsoft',
#  'Music',
#  'My Documents',
#  'NetHood',
#  'New folder',
#  'NTUSER.DAT',
#  'ntuser.dat.LOG1',
#  'ntuser.dat.LOG2',
#  'NTUSER.DAT{13c28a8d-36ed-11f0-8b4d-a8e291286d6f}.TM.blf',
#  'NTUSER.DAT{13c28a8d-36ed-11f0-8b4d-a8e291286d6f}.TMContainer00000000000000000001.regtrans-ms',
#  'NTUSER.DAT{13c28a8d-36ed-11f0-8b4d-a8e291286d6f}.TMContainer00000000000000000002.regtrans-ms',
#  'ntuser.ini',
#  'OneDrive',
#  'op_sun_pandas.ipynb',
#  'PrintHood',
#  'Recent',
#  'Saved Games',
#  'Searches',
#  'SendTo',
#  'Start Menu',
# ...

# %%
import os
os.startfile(os.getcwd())
